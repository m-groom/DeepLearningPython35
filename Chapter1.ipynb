# %% [markdown]
# ## Default network from Chapter 1:

# %%
import mnist_loader, network
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
net = network.Network([784, 30, 10])
net.SGD(training_data, 30, 10, 3.0, test_data=test_data)
# Out:
# Epoch 0 : 9019 / 10000
# Epoch 1 : 9244 / 10000
# Epoch 2 : 9300 / 10000
# Epoch 3 : 9328 / 10000
# Epoch 4 : 9356 / 10000
# Epoch 5 : 9387 / 10000
# Epoch 6 : 9395 / 10000
# Epoch 7 : 9406 / 10000
# Epoch 8 : 9429 / 10000
# Epoch 9 : 9419 / 10000
# Epoch 10 : 9440 / 10000
# Epoch 11 : 9439 / 10000
# Epoch 12 : 9442 / 10000
# Epoch 13 : 9413 / 10000
# Epoch 14 : 9442 / 10000
# Epoch 15 : 9446 / 10000
# Epoch 16 : 9452 / 10000
# Epoch 17 : 9429 / 10000
# Epoch 18 : 9435 / 10000
# Epoch 19 : 9446 / 10000
# Epoch 20 : 9435 / 10000
# Epoch 21 : 9443 / 10000
# Epoch 22 : 9452 / 10000
# Epoch 23 : 9471 / 10000
# Epoch 24 : 9438 / 10000
# Epoch 25 : 9436 / 10000
# Epoch 26 : 9436 / 10000
# Epoch 27 : 9451 / 10000
# Epoch 28 : 9442 / 10000
# Epoch 29 : 9454 / 10000

# %% [markdown]
# ## Exercise 8:

# %%
import mnist_loader, network
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
net2 = network.Network([784, 10])
net2.SGD(training_data, 30, 10, 3.0, test_data=test_data)
# Out:
# Epoch 0 : 5146 / 10000
# Epoch 1 : 5726 / 10000
# Epoch 2 : 6613 / 10000
# Epoch 3 : 6641 / 10000
# Epoch 4 : 6699 / 10000
# Epoch 5 : 7546 / 10000
# Epoch 6 : 7559 / 10000
# Epoch 7 : 7559 / 10000
# Epoch 8 : 7559 / 10000
# Epoch 9 : 7583 / 10000
# Epoch 10 : 7575 / 10000
# Epoch 11 : 7573 / 10000
# Epoch 12 : 7586 / 10000
# Epoch 13 : 8270 / 10000
# Epoch 14 : 8331 / 10000
# Epoch 15 : 8345 / 10000
# Epoch 16 : 8351 / 10000
# Epoch 17 : 8359 / 10000
# Epoch 18 : 8341 / 10000
# Epoch 19 : 8374 / 10000
# Epoch 20 : 8348 / 10000
# Epoch 21 : 9119 / 10000
# Epoch 22 : 9139 / 10000
# Epoch 23 : 9174 / 10000
# Epoch 24 : 9148 / 10000
# Epoch 25 : 9165 / 10000
# Epoch 26 : 9154 / 10000
# Epoch 27 : 9142 / 10000
# Epoch 28 : 9195 / 10000
# Epoch 29 : 9165 / 10000
